# %%
import random
from modulefinder import packagePathMap

suit=("Hearts","Diamond","Club","Spades")
rank=('Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
#Card Class
class Card:

     def __init__(self,suit,rank):
         self.suit = suit
         self.rank = rank
         self.values = values[rank]

     def __str__(self):
         return  f'{self.suit}  of  {self.rank}'

# %%
two_hearts =Card('hearts','Two')
print(two_hearts)

# %%
class Deck:

    def __init__(self):
        self.all_cards=[]
        for suits in suit:
            for ranks in rank:
                card=Card(suits,ranks)
                self.all_cards.append(card)

    def Shuffle(self):
        #we can also use just shuffle method
        random.shuffle(self.all_cards)

    def Deal_one(self):
        return self.all_cards.pop()

# %%
deck=Deck()
# for card in deck.all_cards:
#     print(card)
deck.Shuffle()
print(deck.all_cards[0])
print(deck.Deal_one())
print(len(deck.all_cards))

# %%
#player Classs
class Player():

    def __init__(self,name):
        self.name=name
        self.all_cards=[]

    def remove_one(self):
        return self.all_cards.pop(0)

    def add_cards(self,new_card):
        if type(new_card)==type([]):
            #list of multiple card objects
            self.all_cards.extend(new_card)
        else:
            #for a single card objects
            self.all_cards.append(new_card)

    def __str__(self) -> str:
        return f'{self.name} has {len(self.all_cards)} cards'

# %%
player=Player('Vikas')
print(player)
player.add_cards(deck.Deal_one())
print(player)
print(player.all_cards[0])

# %%
#game set-up
player1=Player('Vikas')
player2=Player('Vikas Bhat')

#shuffle the deck
new_deck=Deck()
new_deck.Shuffle()

#distributing the shuffled deck
for x in range(26):
    player1.add_cards((new_deck.Deal_one()))
    player2.add_cards((new_deck.Deal_one()))

# %%
#game on rule
game=True
round_number=0
while game:
    round_number+=1
    print(f'Round-{round_number}')

    if len(player1.all_cards)==0:
        print(f'Player {player1.name} has no card so {player2.name} has won the game')
        game=False
        break

    if len(player2.all_cards)==0:
        print(f'Player {player2.name} has no card so {player1.name} has won the game')
        game=False
        break

    #starting of the round
    player_one_cards=[]
    player_one_cards.append(player1.remove_one())
    player_two_cards=[]
    player_two_cards.append(player2.remove_one())

    #at game
    at_game=True
    while at_game:

        if player_one_cards[-1].values > player_two_cards[-1].values:
            player1.add_cards(player_one_cards)
            player1.add_cards(player_two_cards)
            at_game=False

        elif player_two_cards[-1].values> player_one_cards[-1].values:
            player2.add_cards(player_two_cards)
            player2.add_cards(player_one_cards)
            at_game=False

        else:
            print("WAR!")

            if len(player1.all_cards)<3:
                print("Player 1 unable to play the wargame")
                print("Player 2 Won the game")
                game=False
                break

            elif len(player2.all_cards)<3: # this the minimum rule setted by us can be any line
                print("Player 2 unable to play the wargame")
                print("Player 1 Won the game")
                game=False
                break

            else:
                for num in range(3):
                    player_one_cards.append(player1.remove_one())
                    player_two_cards.append(player2.remove_one())
